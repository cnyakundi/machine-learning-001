# %% [markdown]
# # Challenge
#
# We will bring this all together by adapting a challenge from data.world. In the code section below you have access to a large dataset with demographic and medical data for cancer occurances in regions in the US. Your aim is to build a model that predicts the **target_deathrate** variable. You can find descriptions of all the columns [here](https://data.world/exercises/linear-regression-exercise-1)
#
# This is a holistic challenge:
#
#
# *   Make sure to clean up your data first, there are some missing elements.
# *   Some data should be changed: Add a **state** column which indicates the state a person lives in(you can modify the geography column). Perform a multicollinearity test: Should **state** be included in your model or not?
# * If it should be, make sure to transform it since we want to be dealing with numerical data.
# * Build a model, then display the residual plot for it. Perform a Bartlett test to determine if your model is acceptable or not.

# %%
#Loading the libraries 

import pandas as pd

import numpy as np 

import matplotlib.pyplot as plt

import seaborn as sns 

# %matplotlib inline

# %%
df=pd.read_csv("../cancer_reg.csv")

# %%
#Preview the dataset 

df.head()
# Out:
#    avganncount  avgdeathsperyear  target_deathrate  incidencerate  medincome  \
# 0       1397.0               469             164.9          489.8      61898
# 1        173.0                70             161.3          411.6      48127
# 2        102.0                50             174.7          349.7      49348
# 3        427.0               202             194.8          430.4      44243
# 4         57.0                26             144.4          350.1      49955
#
#    popest2015  povertypercent  studypercap           binnedinc  medianage  \
# 0      260131            11.2   499.748204   (61494.5, 125635]       39.3
# 1       43269            18.6    23.111234  (48021.6, 51046.4]       33.0
# 2       21026            14.6    47.560164  (48021.6, 51046.4]       45.0
# 3       75882            17.1   342.637253    (42724.4, 45201]       42.8
# 4       10321            12.5     0.000000  (48021.6, 51046.4]       48.3
#
#    ...  pctprivatecoveragealone  pctempprivcoverage pctpubliccoverage  \
# 0  ...                      NaN                41.6              32.9
# 1  ...                     53.8                43.6              31.1
# 2  ...                     43.5                34.9              42.1
# 3  ...                     40.3                35.0              45.3
# 4  ...                     43.9                35.1              44.0
#
#    pctpubliccoveragealone   pctwhite  pctblack  pctasian  pctotherrace  \
# 0                    14.0  81.780529  2.594728  4.821857      1.843479
# 1                    15.3  89.228509  0.969102  2.246233      3.741352
# 2                    21.1  90.922190  0.739673  0.465898      2.747358
# 3                    25.0  91.744686  0.782626  1.161359      1.362643
# 4                    22.7  94.104024  0.270192  0.665830      0.492135
#
#    pctmarriedhouseholds  birthrate
# 0             52.856076   6.118831
# 1             45.372500   4.333096
# 2             54.444868   3.729488
# 3             51.021514   4.603841
# 4             54.027460   6.796657
#
# [5 rows x 33 columns]

# %%
df.corr()
# Out:
#                          avganncount  avgdeathsperyear  target_deathrate  \
# avganncount                 1.000000          0.939408         -0.143532
# avgdeathsperyear            0.939408          1.000000         -0.090715
# target_deathrate           -0.143532         -0.090715          1.000000
# incidencerate               0.073553          0.062690          0.449432
# medincome                   0.269145          0.223207         -0.428615
# popest2015                  0.926894          0.977634         -0.120073
# povertypercent             -0.135694         -0.066918          0.429389
# studypercap                 0.082071          0.063488         -0.022285
# medianage                  -0.024098         -0.024599          0.004375
# medianagemale              -0.124969         -0.148487         -0.021929
# medianagefemale            -0.122844         -0.144069          0.012048
# percentmarried             -0.106108         -0.181029         -0.266820
# pctnohs18_24               -0.143327         -0.136794          0.088463
# pcths18_24                 -0.182054         -0.151418          0.261976
# pctsomecol18_24             0.109455          0.098464         -0.188688
# pctbachdeg18_24             0.284176          0.259761         -0.287817
# popest2015                  0.055722  -0.025219      -0.176608  ...
# povertypercent             -0.055652  -0.029280      -0.214001  ...
# studypercap                 1.000000  -0.026030      -0.036647  ...
# medianage                  -0.026030   1.000000       0.129119  ...
# medianagemale              -0.036647   0.129119       1.000000  ...
# medianagefemale            -0.030577   0.124678       0.933696  ...
# percentmarried             -0.038143   0.046372       0.449986  ...
# pctnohs18_24               -0.090387   0.006178       0.100486  ...
# pcths18_24                 -0.057035   0.050574       0.241310  ...
# pctsomecol18_24             0.101220  -0.018325      -0.274801  ...
# pctbachdeg18_24             0.063819  -0.016909      -0.034135  ...
# pcths25_over               -0.085128   0.036587       0.318277  ...
# pctbachdeg25_over           0.108594  -0.020352      -0.131599  ...
# pctemployed16_over          0.088021  -0.024650      -0.165199  ...
# pctunemployed16_over       -0.031957   0.018590      -0.142737  ...
# pctprivatecoverage          0.092545   0.004665       0.082232  ...
# pctprivatecoveragealone     0.072381  -0.024272      -0.167064  ...
# pctempprivcoverage          0.100063  -0.036926      -0.208664  ...
# pctpubliccoverage          -0.051497   0.049060       0.398967  ...
# pctpubliccoveragealone     -0.055512  -0.003298       0.002479  ...
# pctwhite                    0.023291   0.035009       0.398044  ...
# pctblack                   -0.019761  -0.017173      -0.242748  ...
# pctasian                    0.062543  -0.038424      -0.238322  ...
# pctotherrace               -0.015247  -0.030277      -0.266655  ...
# pctmarriedhouseholds       -0.051736   0.014504       0.222278  ...
# birthrate                   0.010676  -0.008276      -0.104105  ...
#
#                          pctprivatecoveragealone  pctempprivcoverage  \
# avganncount                             0.186045            0.202349
# avgdeathsperyear                        0.125820            0.160124
# target_deathrate                       -0.363704           -0.267399
# incidencerate                           0.109278            0.149825
# medincome                               0.788048            0.747294
# popest2015                              0.132660            0.158650
# povertypercent                         -0.761672           -0.683100
# studypercap                             0.072381            0.100063
# medianage                              -0.024272           -0.036926
# medianagemale                          -0.167064           -0.208664
# medianagefemale                        -0.209402           -0.252221
# percentmarried                          0.334155            0.232899
# pctnohs18_24                           -0.457158           -0.429994
# pcths18_24                             -0.292468           -0.244494
# pctsomecol18_24                         0.424226            0.362957
# pctbachdeg18_24                         0.505580            0.450996
# pcths25_over                           -0.309823           -0.222803
# pctbachdeg25_over                       0.652307            0.539084
# pctemployed16_over                      0.782595            0.702786
# pctunemployed16_over                   -0.582054           -0.474745
# pctprivatecoverage                      0.933496            0.827459
# pctprivatecoveragealone                 1.000000            0.929105
# pctempprivcoverage                      0.929105            1.000000
# pctpubliccoverage                      -0.862075           -0.778315
# pctpubliccoveragealone                 -0.856100           -0.728823
# pctwhite                                0.310825            0.269815
# pctblack                               -0.276508           -0.237388
# pctasian                                0.285084            0.282484
# pctotherrace                           -0.087293           -0.064226
# pctmarriedhouseholds                    0.392620            0.322569
# birthrate                              -0.044569           -0.093878
#
#                          pctpubliccoverage  pctpubliccoveragealone  pctwhite  \
# avganncount                      -0.173548               -0.093699 -0.136501
# avgdeathsperyear                 -0.131687               -0.027338 -0.187159
# birthrate               -0.067805 -0.061947      0.059829
#
#                          pctmarriedhouseholds  birthrate
# avganncount                         -0.106221  -0.034508
# avgdeathsperyear                    -0.160266  -0.074420
# target_deathrate                    -0.293325  -0.087407
# incidencerate                       -0.152176  -0.118181
# medincome                            0.446083  -0.010195
# popest2015                          -0.127979  -0.057740
# povertypercent                      -0.604953  -0.012283
# studypercap                         -0.051736   0.010676
# medianage                            0.014504  -0.008276
# medianagemale                        0.222278  -0.104105
# medianagefemale                      0.161507  -0.098813
# percentmarried                       0.870261   0.141404
# pctnohs18_24                         0.005340   0.125895
# pcths18_24                           0.120040   0.058227
# pctsomecol18_24                     -0.060574  -0.063891
# pctbachdeg18_24                     -0.000104  -0.125073
# pcths25_over                         0.062176   0.016600
# pctbachdeg25_over                    0.098134  -0.087940
# pctemployed16_over                   0.314938   0.082241
# pctunemployed16_over                -0.469609  -0.067906
# pctprivatecoverage                   0.434640  -0.040437
# pctprivatecoveragealone              0.392620  -0.044569
# pctempprivcoverage                   0.322569  -0.093878
# pctpubliccoverage                   -0.362171  -0.030531
# pctpubliccoveragealone              -0.473994  -0.004753
# pctwhite                             0.596771  -0.008958
# pctblack                            -0.573592  -0.067805
# pctasian                            -0.086602  -0.061947
# pctotherrace                        -0.027352   0.059829
# pctmarriedhouseholds                 1.000000   0.102263
# birthrate                            0.102263   1.000000
#
# [31 rows x 31 columns]

# %%
#Checking for null values 

df.isnull().values.any()
# Out:
# True

# %%
#Dropping null values

df.dropna(inplace=True)

# %%
#Confirm drop of null values 

df.isnull().values.any()
# Out:
# False

# %%
#Check datatypes

df.dtypes
# Out:
# avganncount                float64
# avgdeathsperyear             int64
# target_deathrate           float64
# incidencerate              float64
# medincome                    int64
# popest2015                   int64
# povertypercent             float64
# studypercap                float64
# binnedinc                   object
# medianage                  float64
# medianagemale              float64
# medianagefemale            float64
# geography                   object
# percentmarried             float64
# pctnohs18_24               float64
# pcths18_24                 float64
# pctsomecol18_24            float64
# pctbachdeg18_24            float64
# pcths25_over               float64
# pctbachdeg25_over          float64
# pctemployed16_over         float64
# pctunemployed16_over       float64
# pctprivatecoverage         float64
# pctprivatecoveragealone    float64
# pctempprivcoverage         float64
# pctpubliccoverage          float64
# pctpubliccoveragealone     float64
# pctwhite                   float64
# pctblack                   float64
# pctasian                   float64
# pctotherrace               float64
# pctmarriedhouseholds       float64
# birthrate                  float64
# dtype: object

# %%
#Check the columns of the table

df.columns
# Out:
# Index(['avganncount', 'avgdeathsperyear', 'target_deathrate', 'incidencerate',
#        'medincome', 'popest2015', 'povertypercent', 'studypercap', 'binnedinc',
#        'medianage', 'medianagemale', 'medianagefemale', 'geography',
#        'percentmarried', 'pctnohs18_24', 'pcths18_24', 'pctsomecol18_24',
#        'pctbachdeg18_24', 'pcths25_over', 'pctbachdeg25_over',
#        'pctemployed16_over', 'pctunemployed16_over', 'pctprivatecoverage',
#        'pctprivatecoveragealone', 'pctempprivcoverage', 'pctpubliccoverage',
#        'pctpubliccoveragealone', 'pctwhite', 'pctblack', 'pctasian',
#        'pctotherrace', 'pctmarriedhouseholds', 'birthrate'],
#       dtype='object')

# %%
# Rename the geograpy column to the name of the geograpy column



df.columns = ['avganncount', 'avgdeathsperyear', 'target_deathrate', 'incidencerate',
       'medincome', 'popest2015', 'povertypercent', 'studypercap', 'binnedinc',
       'medianage', 'medianagemale', 'medianagefemale', 'state',
       'percentmarried', 'pctnohs18_24', 'pcths18_24', 'pctsomecol18_24',
       'pctbachdeg18_24', 'pcths25_over', 'pctbachdeg25_over',
       'pctemployed16_over', 'pctunemployed16_over', 'pctprivatecoverage',
       'pctprivatecoveragealone', 'pctempprivcoverage', 'pctpubliccoverage',
       'pctpubliccoveragealone', 'pctwhite', 'pctblack', 'pctasian',
       'pctotherrace', 'pctmarriedhouseholds', 'birthrate']

# %%
df.columns
# Out:
# Index(['avganncount', 'avgdeathsperyear', 'target_deathrate', 'incidencerate',
#        'medincome', 'popest2015', 'povertypercent', 'studypercap', 'binnedinc',
#        'medianage', 'medianagemale', 'medianagefemale', 'state',
#        'percentmarried', 'pctnohs18_24', 'pcths18_24', 'pctsomecol18_24',
#        'pctbachdeg18_24', 'pcths25_over', 'pctbachdeg25_over',
#        'pctemployed16_over', 'pctunemployed16_over', 'pctprivatecoverage',
#        'pctprivatecoveragealone', 'pctempprivcoverage', 'pctpubliccoverage',
#        'pctpubliccoveragealone', 'pctwhite', 'pctblack', 'pctasian',
#        'pctotherrace', 'pctmarriedhouseholds', 'birthrate'],
#       dtype='object')

# %%
df.head()
# Out:
#     avganncount  avgdeathsperyear  target_deathrate  incidencerate  medincome  \
# 1         173.0                70             161.3          411.6      48127
# 3         427.0               202             194.8          430.4      44243
# 4          57.0                26             144.4          350.1      49955
# 7         146.0                71             183.6          404.0      40189
# 14       2265.0               901             171.0          440.7      50083
#
#     popest2015  povertypercent  studypercap           binnedinc  medianage  \
# 1        43269            18.6    23.111234  (48021.6, 51046.4]       33.0
# 3        75882            17.1   342.637253    (42724.4, 45201]       42.8
# 4        10321            12.5     0.000000  (48021.6, 51046.4]       48.3
# 7        20848            17.8     0.000000  (37413.8, 40362.7]       51.7
# 14      490945            16.3   462.373586  (48021.6, 51046.4]       37.2
#
#     ...  pctprivatecoveragealone  pctempprivcoverage pctpubliccoverage  \
# 1   ...                     53.8                43.6              31.1
# 3   ...                     40.3                35.0              45.3
# 4   ...                     43.9                35.1              44.0
# 7   ...                     33.1                25.9              50.9
# 14  ...                     50.6                42.5              36.5
#
#     pctpubliccoveragealone   pctwhite  pctblack  pctasian  pctotherrace  \
# 1                     15.3  89.228509  0.969102  2.246233      3.741352
# 3                     25.0  91.744686  0.782626  1.161359      1.362643
# 4                     22.7  94.104024  0.270192  0.665830      0.492135
# 7                     24.1  89.406636  0.305159  1.889077      2.286268
# 14                    21.4  89.038167  1.827041  2.315986      1.033625
#
#     pctmarriedhouseholds  birthrate
# 1              45.372500   4.333096
# 3              51.021514   4.603841
# 4              54.027460   6.796657
# 7              48.967033   5.889179
# 14             48.188377   5.355836
#
# [5 rows x 33 columns]

# %%
df['binnedinc']=pd.to_numeric(df['binnedinc'], errors='coerce')

# %%
#We are done! Now get the correlations 


df.corr()
# Out:
# pctprivatecoveragealone       0.173349   0.786730    0.081420       -0.743404
# pctempprivcoverage            0.189013   0.757948    0.091063       -0.674968
# pctpubliccoverage            -0.069795  -0.764296   -0.141193        0.634122
# pctpubliccoveragealone       -0.061571  -0.733614   -0.020699        0.790520
# pctwhite                     -0.029996   0.190445   -0.172378       -0.529978
# pctblack                      0.102696  -0.270956    0.055595        0.528894
# pctasian                      0.076300   0.465658    0.479433       -0.168474
# pctotherrace                 -0.208808   0.078734    0.299631        0.060031
# pctmarriedhouseholds         -0.141188   0.468958   -0.097910       -0.598793
# birthrate                    -0.103238  -0.079201   -0.061795        0.024339
#
#                          studypercap  binnedinc  medianage  ...  \
# avganncount                 0.079980        NaN  -0.026047  ...
# avgdeathsperyear            0.086374        NaN  -0.020042  ...
# target_deathrate           -0.033589        NaN  -0.011419  ...
# incidencerate               0.094944        NaN   0.020339  ...
# medincome                   0.115285        NaN  -0.003541  ...
# popest2015                  0.073192        NaN  -0.021496  ...
# povertypercent             -0.093313        NaN  -0.016437  ...
# studypercap                 1.000000        NaN  -0.027249  ...
# binnedinc                        NaN        NaN        NaN  ...
# medianage                  -0.027249        NaN   1.000000  ...
# medianagemale              -0.060887        NaN   0.075247  ...
# medianagefemale            -0.078092        NaN   0.099255  ...
# percentmarried             -0.031118        NaN   0.027442  ...
# pctnohs18_24               -0.136710        NaN  -0.011858  ...
# pcths18_24                 -0.037298        NaN   0.017716  ...
# pctsomecol18_24             0.081161        NaN  -0.003276  ...
# pctbachdeg18_24             0.125690        NaN  -0.008663  ...
# pcths25_over               -0.151372        NaN   0.048341  ...
# pctbachdeg25_over           0.163404        NaN  -0.026124  ...
# pctemployed16_over          0.171909        NaN  -0.029754  ...
# pctunemployed16_over       -0.045224        NaN   0.051701  ...
# pctprivatecoverage          0.120519        NaN   0.019211  ...
# pctprivatecoveragealone     0.142935        NaN  -0.008464  ...
# pctempprivcoverage          0.155486        NaN  -0.012627  ...
# pctpubliccoverage          -0.113575        NaN   0.034639  ...
# pctpubliccoveragealone     -0.082975        NaN  -0.006858  ...
# pctwhite                    0.021907        NaN   0.016302  ...
# pctblack                   -0.017010        NaN   0.018361  ...
# pctasian                    0.098969        NaN  -0.054970  ...
# pctotherrace                0.003875        NaN  -0.017505  ...
# pctmarriedhouseholds       -0.051405        NaN  -0.005902  ...
# birthrate                  -0.024016        NaN   0.004128  ...
#
#                          pctprivatecoveragealone  pctempprivcoverage  \
# avganncount                             0.133070            0.131033
# avgdeathsperyear                        0.088625            0.105198
# target_deathrate                       -0.322015           -0.228443
# incidencerate                           0.173349            0.189013
# medincome                               0.786730            0.757948
# popest2015                              0.081420            0.091063
# povertypercent                         -0.743404           -0.674968
# studypercap                             0.142935            0.155486
# binnedinc                                    NaN                 NaN
# medianage                              -0.008464           -0.012627
# medianagemale                          -0.190114           -0.217323
# medianagefemale                        -0.232112           -0.252605
# percentmarried                          0.308857            0.213947
# pctnohs18_24                           -0.474478           -0.406897
# pcths18_24                             -0.355788           -0.308553
# pctsomecol18_24                         0.425162            0.365197
# pctbachdeg18_24                         0.561036            0.487006
# pcths25_over                           -0.298786           -0.205677
# pctbachdeg25_over                       0.644950            0.538455
# pctemployed16_over                      0.772177            0.701474
# pctunemployed16_over                   -0.582418           -0.483431
# pctprivatecoverage                      0.937472            0.825219
# pctprivatecoveragealone                 1.000000            0.923300
# pctempprivcoverage                      0.923300            1.000000
# pctpubliccoverage                      -0.873242           -0.793408
# pctpubliccoveragealone                 -0.866388           -0.740792
# pctwhite                                0.339592            0.303572
# pctblack                               -0.297574           -0.266565
# pctasian                                0.339046            0.324893
# pctotherrace                           -0.094952           -0.066815
# pctmarriedhouseholds                    0.414979            0.357945
# birthrate                              -0.071586           -0.134060
#
#                          pctpubliccoverage  pctpubliccoveragealone  pctwhite  \
# avganncount                      -0.164938               -0.072116 -0.138574
# avgdeathsperyear                 -0.137201               -0.019233 -0.179069
# target_deathrate                  0.346525                0.388474 -0.158205
# incidencerate                    -0.069795               -0.061571 -0.029996
# medincome                        -0.764296               -0.733614  0.190445
# popest2015                       -0.141193               -0.020699 -0.172378
# povertypercent                    0.634122                0.790520 -0.529978
# studypercap                      -0.113575               -0.082975  0.021907
# binnedinc                              NaN                     NaN       NaN
# medianage                         0.034639               -0.006858  0.016302
# medianagemale                     0.384922                0.006612  0.416602
# medianagefemale                   0.431501                0.044520  0.353146
# percentmarried                   -0.214393               -0.432733  0.675200
# pctnohs18_24                      0.343423                0.347719 -0.170894
# pcths18_24                        0.299455                0.276442 -0.024144
# pctsomecol18_24                  -0.332502               -0.309187  0.097542
# pctbachdeg18_24                  -0.434681               -0.452202  0.116750
# pcths25_over                      0.407990                0.290024  0.204109
# pctbachdeg25_over                -0.654786               -0.620703  0.051055
# pctemployed16_over               -0.733893               -0.714231  0.320367
# pctunemployed16_over              0.521611                0.655206 -0.515068
# pctprivatecoverage               -0.738893               -0.894908  0.464066
# pctprivatecoveragealone          -0.873242               -0.866388  0.339592
# pctempprivcoverage               -0.793408               -0.740792  0.303572
# pctpubliccoverage                 1.000000                0.873863 -0.160644
# pctpubliccoveragealone            0.873863                1.000000 -0.391729
# pctwhite                         -0.160644               -0.391729  1.000000
# pctblack                          0.218170                0.360467 -0.823827
# pctasian                         -0.397212               -0.251335 -0.230129
# pctotherrace                     -0.065322                0.100183 -0.258264
# pctmarriedhouseholds             -0.377371               -0.479983  0.594213
# birthrate                         0.054282                0.042141 -0.058041
#
#                          pctblack  pctasian  pctotherrace  \
# avganncount              0.020755  0.480718      0.276332
# avgdeathsperyear         0.069639  0.486688      0.285097
# target_deathrate         0.258829 -0.199772     -0.209761
# incidencerate            0.102696  0.076300     -0.208808
# medincome               -0.270956  0.465658      0.078734
# popest2015               0.055595  0.479433      0.299631
# povertypercent           0.528894 -0.168474      0.060031
# studypercap             -0.017010  0.098969      0.003875
# binnedinc                     NaN       NaN           NaN
# medianage                0.018361 -0.054970     -0.017505
# medianagemale           -0.260831 -0.316228     -0.265851
# medianagefemale         -0.176496 -0.326323     -0.274530
# percentmarried          -0.601563 -0.177760     -0.115861
# pctnohs18_24             0.143571 -0.256304      0.147097
# pcths18_24               0.004661 -0.264701     -0.063337
# pctsomecol18_24         -0.063938  0.256255     -0.027608
# pctbachdeg18_24         -0.111149  0.395026     -0.061192
# pcths25_over            -0.056179 -0.509383     -0.295465
# pctbachdeg25_over       -0.135782  0.525482      0.036731
# pctemployed16_over      -0.365914  0.244558      0.057074
# pctunemployed16_over     0.480941  0.017580      0.109169
# pctprivatecoverage      -0.372692  0.227351     -0.187068
# pctprivatecoveragealone -0.297574  0.339046     -0.094952
# pctempprivcoverage      -0.266565  0.324893     -0.066815
# pctpubliccoverage        0.218170 -0.397212     -0.065322
# pctpubliccoveragealone   0.360467 -0.251335      0.100183
# pctwhite                -0.823827 -0.230129     -0.258264
# pctblack                 1.000000  0.032839      0.000885
# pctasian                 0.032839  1.000000      0.265279
# pctotherrace             0.000885  0.265279      1.000000
# pctmarriedhouseholds    -0.550466 -0.061686     -0.039611
# birthrate               -0.007655 -0.106405      0.058841
#
#                          pctmarriedhouseholds  birthrate
# avganncount                         -0.086528  -0.036560
# avgdeathsperyear                    -0.120332  -0.076831
# target_deathrate                    -0.291756  -0.051311
# incidencerate                       -0.141188  -0.103238
# medincome                            0.468958  -0.079201
# popest2015                          -0.097910  -0.061795
# povertypercent                      -0.598793   0.024339
# studypercap                         -0.051405  -0.024016
# binnedinc                                 NaN        NaN
# medianage                           -0.005902   0.004128
# medianagemale                        0.206939  -0.037352
# medianagefemale                      0.134338  -0.019152
# percentmarried                       0.846500   0.098926
# pctnohs18_24                        -0.023050   0.119323
# pcths18_24                           0.061143   0.029158
# pctsomecol18_24                     -0.050606  -0.062931
# pctbachdeg18_24                      0.039287  -0.121843
# pcths25_over                         0.064186   0.039364
# pctbachdeg25_over                    0.126635  -0.102401
# pctemployed16_over                   0.338397   0.064328
# pctunemployed16_over                -0.445095  -0.086350
# pctprivatecoverage                   0.461837  -0.048782
# pctprivatecoveragealone              0.414979  -0.071586
# pctempprivcoverage                   0.357945  -0.134060
# pctpubliccoverage                   -0.377371   0.054282
# pctpubliccoveragealone              -0.479983   0.042141
# pctwhite                             0.594213  -0.058041
# pctblack                            -0.550466  -0.007655
# pctasian                            -0.061686  -0.106405
# pctotherrace                        -0.039611   0.058841
# pctmarriedhouseholds                 1.000000   0.018486
# birthrate                            0.018486   1.000000
#
# [32 rows x 32 columns]

# %%
#Plotting the correlations between the two data sets


sns.heatmap(df)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-46-e76dec34d9b4> in <module>
#       2
#       3
# ----> 4 sns.heatmap(df)
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/seaborn/matrix.py in heatmap(data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, linewidths, linecolor, cbar, cbar_kws, cbar_ax, square, xticklabels, yticklabels, mask, ax, **kwargs)
#     538     """
#     539     # Initialize the plotter object
# --> 540     plotter = _HeatMapper(data, vmin, vmax, cmap, center, robust, annot, fmt,
#     541                           annot_kws, cbar, cbar_kws, xticklabels,
#     542                           yticklabels, mask)
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/seaborn/matrix.py in __init__(self, data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, cbar, cbar_kws, xticklabels, yticklabels, mask)
#     157
#     158         # Determine good default values for the colormapping
# --> 159         self._determine_cmap_params(plot_data, vmin, vmax,
#     160                                     cmap, center, robust)
#     161
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/seaborn/matrix.py in _determine_cmap_params(self, plot_data, vmin, vmax, cmap, center, robust)
#     191
#     192         # plot_data is a np.ma.array instance
# --> 193         calc_data = plot_data.astype(float).filled(np.nan)
#     194         if vmin is None:
#     195             if robust:
#
# ValueError: could not convert string to float: 'Kittitas County, Washington'
